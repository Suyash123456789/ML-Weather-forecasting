# %%
import requests
from bs4 import BeautifulSoup
url="https://codewithharry.com"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)

# %%
soup=BeautifulSoup(htmlcontent,"html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9655830461045889"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# ...

# %%
title=soup.title
print(title)
# Out:
# <title>Home | CodeWithHarry</title>

# %%
paras=soup.find_all('p')
#paras
parasa=soup.find_all('a')
#parasa

print(soup.find('p')['class'])
# Out:
# ['mt-2', 'text-sm', 'text-gray-500', 'md:text-base']

# %%
print(soup.find_all("p",class_="text-sm"))
# Out:
# [<p class="mt-2 text-sm text-gray-500 md:text-base">Confused on which course to take? I have got you covered. Browse courses and find out the best course for you. Its free! Code With Harry is my attempt to teach basics and those coding techniques to people in short time which took me ages to learn.</p>, <p class="text-sm text-gray-500 sm:ml-4 sm:pl-4 sm:border-l-2 sm:border-gray-200 sm:py-2 sm:mt-0 mt-4 text-center">Copyright © 2022 CodeWithHarry.com</p>]

# %%
print(soup.find('p').get_text())
# Out:
# Confused on which course to take? I have got you covered. Browse courses and find out the best course for you. Its free! Code With Harry is my attempt to teach basics and those coding techniques to people in short time which took me ages to learn.

# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup
s=HTMLSession()
query='mumbai'
url=f"https://www.google.com/search?q=wind+speed+of+{query}"
r =s.get(url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'})
#print(r.html.find('span#wob_tm',first=True).text)
#print(r.html.find('div#wob_wg.wob_noe',first=True).text)
#print(r.html.find('span.wob_t',first=True).text)
print(r.html.find('div#wob_wg.wob_noe span.wob_t',first=True).text)
# Out:
# 0 km/h0 mph
# 3 km/h2 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 13 km/h8 mph
# 21 km/h13 mph
# 19 km/h12 mph
# 11 km/h7 mph
# 5 km/h3 mph
# 6 km/h4 mph
# 8 km/h5 mph
# 6 km/h4 mph
# 10 km/h6 mph
# 19 km/h12 mph
# 19 km/h12 mph
# 11 km/h7 mph
# 5 km/h3 mph
# 3 km/h2 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 8 km/h5 mph
# 18 km/h11 mph
# 18 km/h11 mph
# 10 km/h6 mph
# 5 km/h3 mph
# 3 km/h2 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 16 km/h10 mph
# 18 km/h11 mph
# 10 km/h6 mph
# 3 km/h2 mph
# 3 km/h2 mph
# 5 km/h3 mph
# 6 km/h4 mph
# 10 km/h6 mph
# 18 km/h11 mph
# 16 km/h10 mph
# 8 km/h5 mph
# 5 km/h3 mph
# 3 km/h2 mph
# 6 km/h4 mph
# 8 km/h5 mph
# 11 km/h7 mph
# 18 km/h11 mph
# 19 km/h12 mph
# 11 km/h7 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 6 km/h4 mph
# 10 km/h6 mph
# 14 km/h9 mph
# 14 km/h9 mph
# 6 km/h4 mph
# 5 km/h3 mph
# 3 km/h2 mph
# 6 km/h4 mph
# 5 km/h3 mph
# 10 km/h6 mph
# 14 km/h9 mph
# 16 km/h10 mph
# 6 km/h4 mph
# 3 km/h2 mph
# 3 km/h2 mph
# 5 km/h3 mph
# 5 km/h3 mph
# ...

# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup
s=HTMLSession()
#query='mumbai'
url="https://www.windfinder.com/report/juhu_beach_mumbai"
r =s.get(url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'})
#print(r.html.find('span#wob_tm',first=True).text)
#print(r.html.find('div#wob_wg.wob_noe',first=True).text)
#print(r.html.find('span.wob_t',first=True).text)
print(r.html.find('div.current-wind__info',first=True).text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2956/272899297.py in <module>
#       8 #print(r.html.find('div#wob_wg.wob_noe',first=True).text)
#       9 #print(r.html.find('span.wob_t',first=True).text)
# ---> 10 print(r.html.find('div.current-wind__info',first=True).text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup
s=HTMLSession()
#query='mumbai'
url="https://weather.com/en-IN/weather/today/l/19.08,72.88?par=google"
r =s.get(url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'})
print(r.html.find('div.WeatherDetailsListItem--wxData--2s6HT',first=True))
#print(r.html.find('div#wob_wg.wob_noe',first=True).text)
#print(r.html.find('span.wob_t',first=True).text)
#print(r.html.find('div.current-wind__info',first=True).text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6692/72998016.py in <module>
#       5 url="https://weather.com/en-IN/weather/today/l/19.08,72.88?par=google"
#       6 r =s.get(url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'})
# ----> 7 print(r.html.find('div.WeatherDetailsListItem--wxData--2s6HT',first=True).children)
#       8 #print(r.html.find('div#wob_wg.wob_noe',first=True).text)
#       9 #print(r.html.find('span.wob_t',first=True).text)
#
# AttributeError: 'Element' object has no attribute 'children'

# %%
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/today/l/19.08,72.88?par=google"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
day1=soup.find("span", {"class": "Wind--windWrapper--3aqXJ undefined", "data-testid": "Wind"}).text

# %%
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/bc7797d0f3a030a46ffd2fe99d531f7818ef054a8768ac9988747d5a6f4b7949"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
day2=soup.find("span", {"class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2", "data-testid": "Wind"}).text

# %%
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/bc7797d0f3a030a46ffd2fe99d531f7818ef054a8768ac9988747d5a6f4b7949"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")

speed=soup.find_all("span", {"class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2", "data-testid": "Wind"})
#soup2=BeautifulSoup(speed,"html.parser")
#comment=soup2.span
#comment
speed
# Out:
# [<span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">N <!-- -->6 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">NNW <!-- -->22 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">NNW <!-- -->17 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">NNW <!-- -->20 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">N <!-- -->17 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">NW <!-- -->19 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">NNW <!-- -->16 km/h</span>,
#  <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">NW <!-- -->18 km/h</span>,
# ...

# %%
#mumbai

import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/bc7797d0f3a030a46ffd2fe99d531f7818ef054a8768ac9988747d5a6f4b7949"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
speed=soup.find_all("span", {"class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2", "data-testid": "Wind"})
speed
all_speed=[]
for word in speed:
    all_example = word.get_text()
    all_speed.append(all_example)
    
all_speed
#soup2=BeautifulSoup(speed,"html.parser")
#comment=soup2.span
#comment
#speed
# Out:
# ['WNW 20 km/h',
#  'N 16 km/h',
#  'NW 18 km/h',
#  'N 15 km/h',
#  'NW 19 km/h',
#  'N 16 km/h',
#  'NW 19 km/h',
#  'N 15 km/h',
#  'NNW 21 km/h',
#  'N 19 km/h',
#  'NNW 19 km/h',
#  'N 16 km/h',
#  'SSW 17 km/h',
#  'N 14 km/h',
#  'SSW 17 km/h',
#  'N 14 km/h',
#  'NNW 19 km/h',
#  'NNW 16 km/h',
#  'NW 20 km/h',
#  'NW 16 km/h',
#  'NW 20 km/h',
#  'NNW 16 km/h',
#  'NNW 20 km/h',
#  'NNW 17 km/h',
#  'NW 19 km/h',
#  'NNW 16 km/h',
#  'NW 19 km/h',
#  'NW 16 km/h',
#  'NW 19 km/h',
#  'NNW 17 km/h']

# %%
#mumbai
#getting the live  wind speed and direction
#======================================
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/bc7797d0f3a030a46ffd2fe99d531f7818ef054a8768ac9988747d5a6f4b7949"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
speed=soup.find_all("span", {"class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2", "data-testid": "Wind"})
#print(speed)
all_speed=[]
for word in speed:
    all_example = word.get_text()
    all_speed.append(all_example)
    
#rint(all_speed)
#==================================

#now seperation the wind speed values and typecasting it into int form string
#======================================
wspeed1=[]
for i in all_speed:
    a2=i[-7:-5]
    wspeed1.append(int(a2))
print(wspeed1)
#======================================

#now seperation the wind direction
#======================================
wdir=[]
for i in all_speed:
    a=i[0:3]
    wdir.append(a)
for i in wdir:
     if i=='W 1':
        x=wdir.index(i)
        wdir[x]="W "
print(wdir)
#======================================
# Out:
# [23, 19, 24, 19, 24, 19, 23, 16, 19, 13, 21, 15, 23, 17, 20, 15, 17, 13, 18, 14, 18, 14, 18, 15, 18, 15, 18, 14, 19, 15]
# ['WNW', 'NNW', 'NW ', 'NW ', 'WNW', 'W ', 'W 2', 'SW ', 'SW ', 'WSW', 'WSW', 'WNW', 'WNW', 'WNW', 'SW ', 'SW ', 'SW ', 'SW ', 'SW ', 'SW ', 'SW ', 'W ', 'SW ', 'NW ', 'WNW', 'WNW', 'WSW', 'W ', 'WSW', 'NNW']

# %%
#chennai
#getting the live  wind speed and direction
#======================================
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/680edc8aa8a645e29b5c7528ef5ffeb1a7bc4b825dd02f8ec17574c12f91017d"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
speed2=soup.find_all("span", {"class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2", "data-testid": "Wind"})
#print(speed2)
all_speed2=[]
for word in speed2:
    all_example2 = word.get_text()
    all_speed2.append(all_example2)
    
#all_speed2
#print(all_speed2)
#======================================

#now seperating the wind speed values and typecasting it into int form string
#======================================
wspeed2=[]
for i in all_speed2:
    a1=i[-7:-5]
    wspeed2.append(int(a1))
print(wspeed2)
#print(len(wspeed2))
#======================================

#now seperating the wind direction
#======================================
wdir2=[]
for i in all_speed2:
    a=i[0:3]
    wdir2.append(a)

for i in wdir2:
    if i=='S 1':
        x=wdir2.index(i)
        wdir2[x]="S "
    elif i=='S 2':
        x=wdir2.index(i)
        wdir2[x]="S "
        
print(wdir2)
#======================================
#soup2=BeautifulSoup(speed,"html.parser")
#comment=soup2.span
#comment
#speed
# Out:
# [18, 16, 19, 17, 22, 20, 22, 20, 20, 18, 20, 18, 21, 19, 22, 20, 22, 19, 22, 20, 23, 20, 23, 20, 24, 21, 23, 20, 23, 20]
# ['SSE', 'SSW', 'S ', 'S ', 'S ', 'SSE', 'SSE', 'SSE', 'SSE', 'S ', 'SSE', 'S ', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE', 'SSE']

# %%
#delhi
#getting the live  wind speed and direction
#======================================
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/c6b355c14f71d06998f2f563bbcf7d20916a998d77aa907c7e354657aa458d51"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
speed3=soup.find_all("span", {"class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2", "data-testid": "Wind"})
#print(speed3)
all_speed3=[]
for word in speed3:
    all_example3 = word.get_text()
    all_speed3.append(all_example3)
    
all_speed3
#======================================

#getting wind speed values and converting it into int from string
#======================================
wspeed3=[]
for i in all_speed3:
    a3=i[-7:-5]
    wspeed3.append(int(a3))
print(wspeed3)
#======================================
 
#getting wind direction
#======================================   
wdir3=[]

for i in all_speed3:
    a=i[0:3]
    wdir3.append(a)
for i in wdir3:
    if i=='W 1':
        x=wdir3.index(i)
        wdir3[x]="W "
    elif i=='W 9':
        x=wdir3.index(i)
        wdir3[x]="W "
#======================================   

print(wdir3)
   
    
#soup2=BeautifulSoup(speed,"html.parser")
#comment=soup2.span
#comment
#speed
# Out:
# [25, 15, 10, 8, 12, 7, 9, 7, 12, 9, 15, 11, 16, 12, 15, 12, 15, 12, 18, 15, 18, 15, 18, 14, 15, 12, 17, 14, 17, 14]
# ['WNW', 'WNW', 'NW ', 'ESE', 'SE ', 'ESE', 'SSW', 'SSE', 'WSW', 'W ', 'WNW', 'WNW', 'WNW', 'W ', 'W ', 'W ', 'W ', 'W ', 'WNW', 'W ', 'W ', 'W ', 'WNW', 'W ', 'W ', 'W ', 'W ', 'W ', 'W ', 'W ']

# %%
#mumbai 
#getting the humidity
#======================================
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/d7a5333ba0420943bb2ec89f99f411f2f8e74d683fdc6c5cb309bc19ec107711#detailIndex5"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
hum1=soup.find_all("span", {"class": "DetailsTable--value--1q_qD", "data-testid": "PercentageValue"})
#print(hum1)
all_hum1=[]
for word in hum1:
    all_humx = word.get_text()
    all_hum1.append(all_humx)
print(all_hum1)
#======================================

#converting the string percentage values into integer
#======================================
mhum=[]
for i in all_hum1:
    a=i[0:2]
    x=(int(a)/100)
    mhum.append(x)    
print(mhum)
#======================================
# Out:
# ['35%', '42%', '36%', '50%', '41%', '55%', '47%', '60%', '57%', '66%', '54%', '62%', '44%', '53%', '46%', '60%', '51%', '63%', '53%', '62%', '50%', '58%', '44%', '53%', '40%', '53%', '42%', '55%', '44%', '55%']
# [0.35, 0.42, 0.36, 0.5, 0.41, 0.55, 0.47, 0.6, 0.57, 0.66, 0.54, 0.62, 0.44, 0.53, 0.46, 0.6, 0.51, 0.63, 0.53, 0.62, 0.5, 0.58, 0.44, 0.53, 0.4, 0.53, 0.42, 0.55, 0.44, 0.55]

# %%
#chennai 
#getting the humidity
#======================================
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/680edc8aa8a645e29b5c7528ef5ffeb1a7bc4b825dd02f8ec17574c12f91017d#detailIndex5"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
hum2=soup.find_all("span", {"class": "DetailsTable--value--1q_qD", "data-testid": "PercentageValue"})
#print(hum2)
all_hum2=[]
for word in hum2:
    all_humx = word.get_text()
    all_hum2.append(all_humx)
print(all_hum2)
#======================================

#converting the string percentage values into integer
#======================================
chum=[]
for i in all_hum2:
    a=i[0:2]
    x=(int(a)/100)
    chum.append(x)    
print(chum)
#======================================
# Out:
# ['59%', '85%', '64%', '85%', '72%', '85%', '72%', '84%', '72%', '84%', '72%', '86%', '72%', '87%', '74%', '86%', '74%', '85%', '74%', '86%', '74%', '85%', '73%', '84%', '72%', '85%', '72%', '85%', '71%', '83%']
# [0.59, 0.85, 0.64, 0.85, 0.72, 0.85, 0.72, 0.84, 0.72, 0.84, 0.72, 0.86, 0.72, 0.87, 0.74, 0.86, 0.74, 0.85, 0.74, 0.86, 0.74, 0.85, 0.73, 0.84, 0.72, 0.85, 0.72, 0.85, 0.71, 0.83]

# %%
#delhi
#getting the humidity
#======================================
import requests
from bs4 import BeautifulSoup
url="https://weather.com/en-IN/weather/tenday/l/c6b355c14f71d06998f2f563bbcf7d20916a998d77aa907c7e354657aa458d51#detailIndex5"
#get the html
r =requests.get(url)
htmlcontent=r.content
#print(htmlcontent)
soup=BeautifulSoup(htmlcontent,"html.parser")
hum3=soup.find_all("span", {"class": "DetailsTable--value--1q_qD", "data-testid": "PercentageValue"})
#print(hum3)
all_hum3=[]
for word in hum3:
    all_humx = word.get_text()
    all_hum3.append(all_humx)
print(all_hum3)
#======================================

#converting the string percentage values into integer
#======================================
dhum=[]
for i in all_hum3:
    a=i[0:2]
    x=(int(a)/100)
    dhum.append(x)    
print(dhum)
#======================================
# Out:
# ['31%', '62%', '50%', '72%', '51%', '69%', '46%', '62%', '40%', '53%', '38%', '45%', '32%', '38%', '29%', '38%', '27%', '35%', '25%', '32%', '22%', '30%', '23%', '32%', '23%', '32%', '23%', '32%', '24%', '33%']
# [0.31, 0.62, 0.5, 0.72, 0.51, 0.69, 0.46, 0.62, 0.4, 0.53, 0.38, 0.45, 0.32, 0.38, 0.29, 0.38, 0.27, 0.35, 0.25, 0.32, 0.22, 0.3, 0.23, 0.32, 0.23, 0.32, 0.23, 0.32, 0.24, 0.33]
